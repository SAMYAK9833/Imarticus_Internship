# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Employee_1000.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  1000 non-null   object
#  1   JoiningYear                1000 non-null   int64
#  2   City                       1000 non-null   object
#  3   PaymentTier                1000 non-null   int64
#  4   Age                        1000 non-null   int64
#  5   Gender                     1000 non-null   object
#  6   EverBenched                1000 non-null   object
#  7   ExperienceInCurrentDomain  1000 non-null   int64
#  8   LeaveOrNot                 1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0        PhD         2018       Pune            1   39  Female          No
# 1  Bachelors         2022       Pune            1   44  Female          No
# 2  Bachelors         2016       Pune            2   33  Female          No
# 3        PhD         2019  New Delhi            1   32  Female          No
# 4    Masters         2019  New Delhi            2   34  Female         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          3           1
# 1                          2           1
# 2                          6           1
# 3                          9           0
# 4                          0           1

# %%
df.tail()
# Out:
#      Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 995        PhD         2019       Pune            1   31  Female          No
# 996    Masters         2012       Pune            1   42  Female          No
# 997  Bachelors         2015  New Delhi            1   25  Female          No
# 998  Bachelors         2015  Bangalore            1   44  Female          No
# 999  Bachelors         2014  New Delhi            1   21  Female          No
#
#      ExperienceInCurrentDomain  LeaveOrNot
# 995                          9           1
# 996                          2           0
# 997                          8           1
# 998                          5           1
# 999                          5           1

# %%
df.head(275)
# Out:
#      Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0          PhD         2018       Pune            1   39  Female          No
# 1    Bachelors         2022       Pune            1   44  Female          No
# 2    Bachelors         2016       Pune            2   33  Female          No
# 3          PhD         2019  New Delhi            1   32  Female          No
# 4      Masters         2019  New Delhi            2   34  Female         Yes
# ..         ...          ...        ...          ...  ...     ...         ...
# 270  Bachelors         2017       Pune            3   43    Male         Yes
# 271  Bachelors         2011       Pune            2   32  Female          No
# 272        PhD         2018  Bangalore            1   35    Male         Yes
# 273    Masters         2017  New Delhi            1   44  Female         Yes
# 274    Masters         2010  Bangalore            3   23  Female         Yes
#
#      ExperienceInCurrentDomain  LeaveOrNot
# ...

# %%
df.iloc[275]
# Out:
# Education                    Masters
# JoiningYear                     2021
# City                            Pune
# PaymentTier                        3
# Age                               39
# Gender                        Female
# EverBenched                      Yes
# ExperienceInCurrentDomain          2
# LeaveOrNot                         0
# Name: 275, dtype: object

# %%
df.iloc[3]
# Out:
# Education                          PhD
# JoiningYear                       2019
# City                         New Delhi
# PaymentTier                          1
# Age                                 32
# Gender                          Female
# EverBenched                         No
# ExperienceInCurrentDomain            9
# LeaveOrNot                           0
# Name: 3, dtype: object

# %%
df.iloc[775]
# Out:
# Education                     PhD
# JoiningYear                  2012
# City                         Pune
# PaymentTier                     2
# Age                            38
# Gender                       Male
# EverBenched                   Yes
# ExperienceInCurrentDomain       2
# LeaveOrNot                      0
# Name: 775, dtype: object

# %%
df.describe()
# Out:
#        JoiningYear  PaymentTier         Age  ExperienceInCurrentDomain  \
# count  1000.000000  1000.000000  1000.00000                1000.000000
# mean   2016.125000     2.012000    32.70200                   5.002000
# std       3.698791     0.813952     7.24912                   3.225896
# min    2010.000000     1.000000    21.00000                   0.000000
# 25%    2013.000000     1.000000    26.00000                   2.000000
# 50%    2016.000000     2.000000    32.00000                   5.000000
# 75%    2019.000000     3.000000    39.00000                   8.000000
# max    2022.000000     3.000000    45.00000                  10.000000
#
#         LeaveOrNot
# count  1000.000000
# mean      0.519000
# std       0.499889
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
sns.countplot(df['City'])
# Out:
# <Axes: xlabel='count', ylabel='City'>

# %%
df['Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
df['Education'].value_counts()
# Out:
# Education
# Bachelors    338
# PhD          335
# Masters      327
# Name: count, dtype: int64

# %%
df['Gender'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    504
# Male      496
# Name: count, dtype: int64

# %%
plt.hist(df['Age'],bins=5)
# Out:
# (array([211., 209., 195., 192., 193.]),
#  array([21. , 25.8, 30.6, 35.4, 40.2, 45. ]),
#  <BarContainer object of 5 artists>)

# %%
sns.distplot(df['Age'], kde=True)
# Out:
# /tmp/ipython-input-1052970539.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], kde=True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.scatterplot(x=df['Age'], y=df['LeaveOrNot'])
# Out:
# <Axes: xlabel='Age', ylabel='LeaveOrNot'>

# %%
sns.barplot(x=df['Education'],y=df['Age'],hue=df['Gender'])
# Out:
# <Axes: xlabel='Education', ylabel='Age'>

# %%
sns.boxplot(x=df['Education'],y=df['Age'],hue=df['Gender'])
# Out:
# <Axes: xlabel='Education', ylabel='Age'>

# %%
sns.lineplot(data=df, x='Age', y='LeaveOrNot')
# Out:
# <Axes: xlabel='Age', ylabel='LeaveOrNot'>

# %%
df.groupby('Education')['Age'].mean().reset_index()
# Out:
#    Education        Age
# 0  Bachelors  32.541420
# 1    Masters  32.431193
# 2        PhD  33.128358

# %%
numerical_df = df.select_dtypes(include=['number'])
sns.heatmap(numerical_df.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)
